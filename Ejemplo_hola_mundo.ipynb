# %% [markdown]
# <a href="https://colab.research.google.com/github/Velgarath/dev/blob/main/Ejemplo_hola_mundo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hola Mundo!")
lista = [
    {"Nombre":"Luis", "Edad": 50},
    {"Nombre":"Genaro", "Edad": 48}
    ]
for item in lista:
  print (item)

f = open("/content/archivo.txt", "w")
f.write("Hola Mundo")
f.close()
# Out:
# Hola Mundo!
# {'Nombre': 'Luis', 'Edad': 50}
# {'Nombre': 'Genaro', 'Edad': 48}

# %% [markdown]
# To download the file `archivo.txt` from Colab to your local computer, you can use the following Python code:

# %%
from google.colab import files

files.download('/content/archivo.txt')

# %% [markdown]
# After running this cell, a download prompt should appear in your browser, allowing you to save the file to your local machine.

# %% [markdown]
# To list the files in the current working directory, you can use the `!ls` command:

# %%
# !ls
# Out:
#  archivo.txt  'c:'$'\a''rchivo.txt'   sample_data

# %% [markdown]
# To list files in a specific directory, for example, the `/content` directory, you can use:

# %%
# !ls /content
# Out:
#  archivo.txt  'c:'$'\a''rchivo.txt'   sample_data

# %% [markdown]
# You can also navigate through the file system using the file browser on the left sidebar of your Colab notebook. Look for the folder icon, click on it, and you'll see a panel that allows you to browse, upload, and download files.
